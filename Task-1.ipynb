# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
#1.Data Loading
#Load the dataset
file_path = r"C:\Users\Fazal\OneDrive\Desktop\Internship\Task-1\student\student-mat.csv"
df = pd.read_csv(file_path, sep=";")
print("The first 5 rows of the dataset are:")
print(df.head()) #display first 5 rows

#2.Data Exploration
#Checking for missing values
print("\nMissing Values:\n")
print(df.isnull().sum())
#Displaying column data types
print("\nData Types of columns are:\n")
print(df.dtypes)
#Understanding dataset size
print("\nDataset size:\n")
print(df.shape)

#3.Data Cleaning
#Handling missing values
df.fillna(df.median(numeric_only=True), inplace=True)
print(df)
#Removing duplicates
df.drop_duplicates(inplace=True)
print(df)

#4.Data Analysis Questions
#Q1. What is the average score in math (G3)?
average_G3 = int(df["G3"].mean())
print("Average score in maths (G3) is:", average_G3)
#Q2. How many students scored above 15 in their final grade (G3)?
students_above_15 = df[df["G3"] > 15].shape[0]
print(f"Number of students scoring above 15 in G3: {students_above_15}")
#Q3. Is there a correlation between study time (study time) and the final grade (G3)?
corr = df["studytime"].corr(df["G3"])
print(f"Correlation between study time and final grade(G3): {corr:.2f}")
#Q4. Which gender has a higher average final grade (G3)?
avg_male = df[df["sex"] == "M"]["G3"].mean()
avg_female = df[df["sex"] == "F"]["G3"].mean()
if avg_male > avg_female:
    print(f"Males have higher average final grade (G3): {avg_male:.2f}")
else:
    print(f"Females have higher average final grade (G3): {avg_feamle:.2f}")

#5.Data Visualization
# 1. Plot a histogram of final grades (G3_avg)
plt.figure(figsize=(8, 6))
plt.hist(df['G3'], bins=20, edgecolor='black')
plt.title('Histogram of Average Final Grades (G3)')
plt.xlabel('Average Final Grade (G3)')
plt.ylabel('Frequency')
plt.show()

# 2. Create a scatter plot between study time (studytime_mat) and final grade (G3_avg)
plt.figure(figsize=(8, 6))
plt.scatter(df['studytime'], df['G3'])
plt.title('Scatter Plot: Study Time vs. Average Final Grade')
plt.xlabel('Study Time (Mat)')
plt.ylabel('Average Final Grade (G3)')
plt.show()

# 3. Create a bar chart comparing the average scores of male and female students.
gender_avg_grades = df.groupby('sex')['G3'].mean()
plt.figure(figsize=(6, 4))
gender_avg_grades.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Average Final Grade by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Final Grade (G3)')
plt.xticks(rotation=0)
plt.show()
# Out:
# The first 5 rows of the dataset are:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#
# Missing Values:
#
# school        0
# ...
